# %% [markdown]
# # Configuracion eh instalacion de librerias

# %%
# %pip install onshape-to-robot
# Out:
# Requirement already satisfied: onshape-to-robot in c:\users\juane\miniconda3\envs\robot_bpd\lib\site-packages (1.8.2)
# Requirement already satisfied: numpy in c:\users\juane\miniconda3\envs\robot_bpd\lib\site-packages (from onshape-to-robot) (2.2.6)
# Requirement already satisfied: requests in c:\users\juane\miniconda3\envs\robot_bpd\lib\site-packages (from onshape-to-robot) (2.33.1)
# Requirement already satisfied: commentjson in c:\users\juane\miniconda3\envs\robot_bpd\lib\site-packages (from onshape-to-robot) (0.9.0)
# Requirement already satisfied: colorama>=0.4.6 in c:\users\juane\miniconda3\envs\robot_bpd\lib\site-packages (from onshape-to-robot) (0.4.6)
# Requirement already satisfied: numpy-stl in c:\users\juane\miniconda3\envs\robot_bpd\lib\site-packages (from onshape-to-robot) (3.2.0)
# Requirement already satisfied: transforms3d in c:\users\juane\miniconda3\envs\robot_bpd\lib\site-packages (from onshape-to-robot) (0.4.2)
# Requirement already satisfied: python-dotenv in c:\users\juane\miniconda3\envs\robot_bpd\lib\site-packages (from onshape-to-robot) (1.2.2)
# Requirement already satisfied: lark-parser<0.8.0,>=0.7.1 in c:\users\juane\miniconda3\envs\robot_bpd\lib\site-packages (from commentjson->onshape-to-robot) (0.7.8)
# Requirement already satisfied: python-utils>=3.4.5 in c:\users\juane\miniconda3\envs\robot_bpd\lib\site-packages (from numpy-stl->onshape-to-robot) (3.9.1)
# Requirement already satisfied: typing_extensions>3.10.0.2 in c:\users\juane\miniconda3\envs\robot_bpd\lib\site-packages (from python-utils>=3.4.5->numpy-stl->onshape-to-robot) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\juane\miniconda3\envs\robot_bpd\lib\site-packages (from requests->onshape-to-robot) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\juane\miniconda3\envs\robot_bpd\lib\site-packages (from requests->onshape-to-robot) (3.13)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\juane\miniconda3\envs\robot_bpd\lib\site-packages (from requests->onshape-to-robot) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\juane\miniconda3\envs\robot_bpd\lib\site-packages (from requests->onshape-to-robot) (2026.4.22)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# clave acesso: on_uJs33YsaP2uDgDvT7I7Lk
# clave secreta: QV7lUVDkZpj4Z7CQdQzv5cM45qDhCbmZFdLWmWmJ5jzWThMd

# %%
import os 

os.environ['ONSHAPE_API'] = 'https://cad.onshape.com'
os.environ['ONSHAPE_ACCESS_KEY'] = 'on_uJs33YsaP2uDgDvT7I7Lk'
os.environ['ONSHAPE_SECRET_KEY'] = 'QV7lUVDkZpj4Z7CQdQzv5cM45qDhCbmZFdLWmWmJ5jzWThMd'

# %%
# %mkdir -p model
# %echo model/config.json

# %%
# !ping cad.onshape.com

# %%
# !onshape-to-robot model
# Out:
# * onshape-to-robot version 1.8.2
# * Using configuration workspace ID 2ee79dd7520cc42214465bb5 ...
# * Using configuration element ID 7518343c4784b4c1e8e306be ...
# * Retrieving assembly with id 7518343c4784b4c1e8e306be
# + Found DOF: BI (revolute) [-1.571: 1.571]
# + Found DOF: HD (revolute) [-1.571: 1.571]
# + Found DOF: HI (revolute) [-1.571: 1.571]
# + Found DOF: BD (revolute) [-1.571: 1.571]
# + Found DOF: HEAD (revolute) [-1.571: 1.571]
# + Found DOF: CI (revolute) [-1.571: 1.571]
# + Found DOF: CD (revolute) [-1.571: 1.571]
# + Found DOF: LD (revolute) [-1.571: 1.571]
# + Found DOF: LI (revolute) [-1.571: 1.571]
# + Found DOF: KI (revolute) [-1.571: 1.571]
# + Found DOF: KD (revolute) [-1.571: 1.571]
# + Found DOF: FI (revolute) [-1.571: 1.571]
# + Found DOF: FD (revolute) [-1.571: 1.571]
# * Found total 13 degrees of freedom
# * Found 1 root nodes:
#   - CBH_D <1>
#
# + Adding part CBH_D <1>
# + Adding part BRZ_D <1>
# + Adding part Part 1 <1>
# + Adding part SRVHB_D <1>
# + Adding part SHL_D <1>
# + Adding part Pecho <1>
# + Adding part CBH_D <2>
# + Adding part Cadera <1>
# + Adding part CBH_I <2>
# + Adding part Part 1 <1>
# + Adding part SRVHB_I <1>
# + Adding part Part 1 <1>
# + Adding part SRVHB_D <1>
# + Adding part Part 1 <1>
# + Adding part SRVHB_I <1>
# WARNING: Parts with same name "srvhb_i", incrementing STL name to "srvhb_i__2"
# + Adding part Part 1 <1>
# + Adding part SRVHB_D <1>
# WARNING: Parts with same name "srvhb_d", incrementing STL name to "srvhb_d__2"
# + Adding part SHL_I <1>
# + Adding part CBH_I <1>
# + Adding part BRZ_I <1>
# + Adding part Part 1 <1>
# + Adding part SRVHB_I <1>
# + Adding part SRVHAD <1>
# + Adding part KNE_I <1>
# + Adding part Part 1 <1>
# + Adding part SRVHB_D <1>
# + Adding part Part 1 <1>
# + Adding part SRVHB_D <1>
# + Adding part ANK_I <1>
# + Adding part FT_I <1>
# + Adding part Part 1 <1>
# + Adding part SRVHB_I <1>
# + Adding part KNE_D <1>
# + Adding part Part 1 <1>
# + Adding part SRVHB_I <1>
# + Adding part Part 1 <1>
# + Adding part SRVHB_I <1>
# + Adding part ANK_D <1>
# + Adding part FT_D <1>
# + Adding part Part 1 <1>
# + Adding part SRVHB_D <1>
# * Writing Bipedo.xml
# * Writing scene.xml

# %%
# %pip install mujoco -q

# %%
import mujoco
import mujoco.viewer

# Cargar modelo
model = mujoco.MjModel.from_xml_path("model/scene.xml")
data = mujoco.MjData(model)

# Inicializar actuadores (opcional)
for i in range(model.nu):
    data.ctrl[i] = 0.0

# Abrir visor interactivo
with mujoco.viewer.launch(model, data) as viewer:

    while viewer.is_running():

        # Simulación
        mujoco.mj_step(model, data)

        # Actualizar visor
        viewer.sync()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 13
#      10     data.ctrl[i] = 0.0
#      12 # Abrir visor interactivo
# ---> 13 with mujoco.viewer.launch(model, data) as viewer:
#      15     while viewer.is_running():
#      16
#      17         # Simulación
#      18         mujoco.mj_step(model, data)
#
# AttributeError: __enter__

# %% [markdown]
# # Verificacion Cuda

# %%
import torch

print("CUDA disponible:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))

# %%
import taichi as ti

for arch in [ti.cpu, ti.vulkan, ti.opengl]:
    try:
        ti.init(arch=arch)
        print(f"{arch} disponible")
    except Exception as e:
        print(f"{arch} NO disponible:", e)

# %%
import taichi as ti
ti.init(arch=ti.vulkan)
